# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioSeveroo/ciencia_de_dados/blob/main/aula05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# usando a função open para abrir um arquivo texto
# se não for especificado o modo de abertura do arquivo, por padrão é 'r' (leitura)
f = open("sample_data/README.md")

#pode ser necessário especificar o tipo de codificação do arquivo
#f = open("sample_data/README.md", mode='r', encoding='utf-8')

# aqui as operaçoes com o arquivo
conteudo = f.readlines()

#fechando o arquivo e liberando os recursos
f.close
# Out:
# <function TextIOWrapper.close()>
